# %%
# import libraries
from Bio import Entrez
import pandas as pd
import numpy as np
import calendar

# %%
# function for search articles
def search_function(query):
    Entrez.email = 'your_email'
    Entrez.api_key = 'your_api_key'
    handle = Entrez.esearch(db='pubmed', sort='relevance', retmax='250000', retmode='xml', term=query)
    results = Entrez.read(handle)
    
    return results

# %%
# the query search algorithm PubMed (for the search function) and Cochrane library (manual search)
query = """(Gut Microbiome OR Gut Microbiomes OR Gut Microflora OR Gut Microbiota OR Gastrointestinal Flora OR 
            Gut Flora OR Gastrointestinal Microbiota OR Gastrointestinal Microbial Community OR 
            Gastrointestinal Microbial Communities OR Intestinal Microbiome OR Intestinal Microflora OR 
            Intestinal Flora OR Gastrointestinal Microflora) AND 
            (Kidney stone disease OR Urolithiasis OR Nephrolithiasis OR gut-kidney axis)"""

# %%
# creating list of PMIDs 
studies = search_function(query)
studies_id_list = studies['IdList']

# %%
# function for fetch details of the articles
def fetch_details(id_list):
    ids = ','.join(id_list)
    Entrez.email = 'your_email'
    Entrez.api_key = 'your_api_key'
    handle = Entrez.efetch(db='pubmed', retmode='xml', id=ids)
    results = Entrez.read(handle)
    
    return results

# %%
# function for export the fetched details of the articles to dataframe 
def articles_info_to_df(id_list):
    # fetch details of the articles
    studies = fetch_details(id_list)
    # size of chunk
    chunk_size = 10000
    
    # declare the lists
    pmid_list = []
    title_list = []
    abstract_list = []
    journal_list = []
    language_list = []
    pubdate_year_list = []
    pubdate_month_list = []
    publication_type_list = []
    elocation_id_list = []
    
    # slicing of the PMIDs list into chunks
    for chunk_i in range(0, len(id_list), chunk_size):
        chunk = id_list[chunk_i:chunk_i + chunk_size]
        papers = fetch_details(chunk)
        
        # iterating over a chunk
        for i, paper in enumerate(papers['PubmedArticle']):
            
            # PMID
            pmid_list.append(paper['MedlineCitation']['PMID'][:])
            
            # Title
            title_list.append(paper['MedlineCitation']['Article']['ArticleTitle'])
        
            # Abstract
            try:
                abstract_list.append(paper['MedlineCitation']['Article']['Abstract']['AbstractText'][0])
            except Exception:
                abstract_list.append('No Abstract')
            
            # Journal
            journal_list.append(paper['MedlineCitation']['Article']['Journal']['Title'])
            
            # Language of Publication
            language_list.append(paper['MedlineCitation']['Article']['Language'][0])
            
            # Year of Publication
            try:
                pubdate_year_list.append(paper['MedlineCitation']['Article']['Journal']['JournalIssue']['PubDate']['Year'])
            except Exception:
                pubdate_year_list.append('No Data')
              
            # Month of Publication
            try:
                pubdate_month_list.append(paper['MedlineCitation']['Article']['Journal']['JournalIssue']['PubDate']['Month'])
            except:
                pubdate_month_list.append('No Data')
            
            # Publication Type
            try:
                publication_type_list.append(", ".join(paper['MedlineCitation']['Article']['PublicationTypeList']))
            except Exception:
                publication_type_list.append('No Data')
            
            # ELocationID
            try:
                elocation_id_list.append(", ".join(paper['MedlineCitation']['Article']['ELocationID']))
            except Exception:
                elocation_id_list.append('No Data')
    
    # export the data to dataframe
    df = pd.DataFrame(list(zip(pmid_list, title_list, abstract_list, journal_list, language_list, pubdate_year_list,
                               pubdate_month_list, publication_type_list, elocation_id_list)),
                      columns=['PMID', 'Title', 'Abstract', 'Journal', 'Language of Publication', 'Year_of_Publication',
                               'Month_of_Publication', 'Publication_Type', 'ELocationID'])
        
    return df

# %%
# export the fetched details of the articles to dataframe 
df_info_articles = articles_info_to_df(studies_id_list)

# %%
# show the dataframe
df_info_articles.head()
# Out:
#        PMID                                              Title  \
# 0  29760448  The gut microbiota and the brain-gut-kidney ax...
# 1  34642783     The mucosal immune system and IgA nephropathy.
# 2  34132361  Recent advances on the mechanisms of kidney st...
# 3  36127409  Mechanisms of the intestinal and urinary micro...
# 4  27847292  The role of the microbiome in kidney stone for...
#
#                                             Abstract  \
# 0  Crosstalk between the gut microbiota and the h...
# 1  The precise pathogenesis of immunoglobulin A n...
# 2  Kidney stone disease is one of the oldest dise...
# 3  Kidney stone disease affects ~10% of the globa...
# 4  Nephrolithiasis is a complex disease of worldw...
#
#                                              Journal Language of Publication  \
# 0                         Nature reviews. Nephrology                     eng
# 1                        Seminars in immunopathology                     eng
# 2        International journal of molecular medicine                     eng
# 3                            Nature reviews. Urology                     eng
# 4  International journal of surgery (London, Engl...                     eng
#
#   Year_of_Publication Month_of_Publication  \
# 0                2018                  Jul
# 1                2021                  Oct
# 2                2021                  Aug
# 3                2022                  Dec
# 4                2016                  Dec
#
#                                     Publication_Type  \
# 0                            Journal Article, Review
# 1  Journal Article, Research Support, Non-U.S. Go...
# 2                            Journal Article, Review
# 3                            Journal Article, Review
# 4                            Journal Article, Review
#
#                                          ELocationID
# 0                          10.1038/s41581-018-0018-2
# 1                         10.1007/s00281-021-00871-y
# 2                        149, 10.3892/ijmm.2021.4982
# 3                         10.1038/s41585-022-00647-5
# 4  10.1016/j.ijsu.2016.11.024, S1743-9191(16)31033-0

# %%
# shape of the dataframe (rows, columns)
df_info_articles.shape
# Out:
# (248, 9)

# %%
# additional PMIDs found from Cochrane library, ClinicalTrials.gov (via Cochrane library) and the systemic review 
additional_studies_id_list = ['29353409', '27115405', '33655334', '29705728', '33404827', '35460343', '27708409', '34427737',
                   '35325834', '27848096', '20736987', '28217694', '29748329', '35571974', '10959618', '15541456',
                   '24643131', '30586752', '29270002', '36126902']

# %%
additional_studies_id_list = list(dict.fromkeys(additional_studies_id_list))

# %%
# export the fetched details of the articles to dataframe 
df_info_articles_additional = articles_info_to_df(additional_studies_id_list)

# %%
# show the dataframe
df_info_articles_additional.head()
# Out:
#        PMID                                              Title  \
# 0  29353409  16S rRNA gene sequencing reveals altered compo...
# 1  27115405  Evidence for a distinct gut microbiome in kidn...
# 2  33655334  Intestinal dysbacteriosis leads to kidney ston...
# 3  29705728  Understanding the gut-kidney axis in nephrolit...
# 4  33404827  Gut microbiota affect the formation of calcium...
#
#                                             Abstract  \
# 0  Nephrolithiasis is a common urological disease...
# 1  The trillions of microbes that colonize our ad...
# 2  The formation and physicochemical properties o...
# 3  The involvement of the gut microbiota in the p...
# 4  Kidney stones are a common and frequently occu...
#
#                                   Journal Language of Publication  \
# 0                            Urolithiasis                     eng
# 1                            Urolithiasis                     eng
# 2              Molecular medicine reports                     eng
# 3                                     Gut                     eng
# 4  Applied microbiology and biotechnology                     eng
#
#   Year_of_Publication Month_of_Publication  \
# 0                2018                  Nov
# 1                2016                  Oct
# 2                2021                  Mar
# 3                2018                  Dec
# 4                2021                  Jan
#
#                      Publication_Type                  ELocationID
# 0                     Journal Article    10.1007/s00240-018-1037-y
# 1  Comparative Study, Journal Article    10.1007/s00240-016-0882-9
# 2                     Journal Article  180, 10.3892/mmr.2020.11819
# 3                     Journal Article   10.1136/gutjnl-2017-315734
# 4                     Journal Article   10.1007/s00253-020-11086-w

# %%
# shape of the dataframe (rows, columns)
df_info_articles_additional.shape
# Out:
# (20, 9)

# %%
# join two dataframes
df_info_articles_concat = pd.concat([df_info_articles, df_info_articles_additional], ignore_index=True, sort=False)

# %%
# show the dataframe
df_info_articles_concat.head()
# Out:
#        PMID                                              Title  \
# 0  29760448  The gut microbiota and the brain-gut-kidney ax...
# 1  34642783     The mucosal immune system and IgA nephropathy.
# 2  34132361  Recent advances on the mechanisms of kidney st...
# 3  36127409  Mechanisms of the intestinal and urinary micro...
# 4  27847292  The role of the microbiome in kidney stone for...
#
#                                             Abstract  \
# 0  Crosstalk between the gut microbiota and the h...
# 1  The precise pathogenesis of immunoglobulin A n...
# 2  Kidney stone disease is one of the oldest dise...
# 3  Kidney stone disease affects ~10% of the globa...
# 4  Nephrolithiasis is a complex disease of worldw...
#
#                                              Journal Language of Publication  \
# 0                         Nature reviews. Nephrology                     eng
# 1                        Seminars in immunopathology                     eng
# 2        International journal of molecular medicine                     eng
# 3                            Nature reviews. Urology                     eng
# 4  International journal of surgery (London, Engl...                     eng
#
#   Year_of_Publication Month_of_Publication  \
# 0                2018                  Jul
# 1                2021                  Oct
# 2                2021                  Aug
# 3                2022                  Dec
# 4                2016                  Dec
#
#                                     Publication_Type  \
# 0                            Journal Article, Review
# 1  Journal Article, Research Support, Non-U.S. Go...
# 2                            Journal Article, Review
# 3                            Journal Article, Review
# 4                            Journal Article, Review
#
#                                          ELocationID
# 0                          10.1038/s41581-018-0018-2
# 1                         10.1007/s00281-021-00871-y
# 2                        149, 10.3892/ijmm.2021.4982
# 3                         10.1038/s41585-022-00647-5
# 4  10.1016/j.ijsu.2016.11.024, S1743-9191(16)31033-0

# %%
# shape of the dataframe (rows, columns)
df_info_articles_concat.shape
# Out:
# (268, 9)

# %%
# drop dublicates
df_info_articles_full = df_info_articles_concat.drop_duplicates(subset=['PMID'])

# %%
# show the dataframe
df_info_articles_full.head()
# Out:
#        PMID                                              Title  \
# 0  29760448  The gut microbiota and the brain-gut-kidney ax...
# 1  34642783     The mucosal immune system and IgA nephropathy.
# 2  34132361  Recent advances on the mechanisms of kidney st...
# 3  36127409  Mechanisms of the intestinal and urinary micro...
# 4  27847292  The role of the microbiome in kidney stone for...
#
#                                             Abstract  \
# 0  Crosstalk between the gut microbiota and the h...
# 1  The precise pathogenesis of immunoglobulin A n...
# 2  Kidney stone disease is one of the oldest dise...
# 3  Kidney stone disease affects ~10% of the globa...
# 4  Nephrolithiasis is a complex disease of worldw...
#
#                                              Journal Language of Publication  \
# 0                         Nature reviews. Nephrology                     eng
# 1                        Seminars in immunopathology                     eng
# 2        International journal of molecular medicine                     eng
# 3                            Nature reviews. Urology                     eng
# 4  International journal of surgery (London, Engl...                     eng
#
#   Year_of_Publication Month_of_Publication  \
# 0                2018                  Jul
# 1                2021                  Oct
# 2                2021                  Aug
# 3                2022                  Dec
# 4                2016                  Dec
#
#                                     Publication_Type  \
# 0                            Journal Article, Review
# 1  Journal Article, Research Support, Non-U.S. Go...
# 2                            Journal Article, Review
# 3                            Journal Article, Review
# 4                            Journal Article, Review
#
#                                          ELocationID
# 0                          10.1038/s41581-018-0018-2
# 1                         10.1007/s00281-021-00871-y
# 2                        149, 10.3892/ijmm.2021.4982
# 3                         10.1038/s41585-022-00647-5
# 4  10.1016/j.ijsu.2016.11.024, S1743-9191(16)31033-0

# %%
# shape of the dataframe (rows, columns)
df_info_articles_full.shape
# Out:
# (255, 9)

# %%
# filter the dataframe by year (No Data)

# %%
df_filtered = df_info_articles_full.copy()

# %%
df_filtered.rename(columns={'Year_of_Publication': 'year'}, inplace=True)
df_filtered.rename(columns={'Month_of_Publication': 'month'}, inplace=True)

# %%
df_year_nodata = df_filtered.loc[df_filtered['year'] == 'No Data']

# %%
# show the dataframe
df_year_nodata.head()
# Out:
#          PMID                                              Title  \
# 263  15541456  Delayed graft function in kidney transplantation.
#
#                                               Abstract  \
# 263  Delayed graft function is a form of acute rena...
#
#                       Journal Language of Publication     year    month  \
# 263  Lancet (London, England)                     eng  No Data  No Data
#
#             Publication_Type ELocationID
# 263  Journal Article, Review

# %%
# shape of the dataframe (rows, columns)
df_year_nodata.shape
# Out:
# (1, 9)

# %%
# filter the dataframe by month (No Data)

# %%
df_month_nodata = df_filtered.loc[(df_filtered['month'] == 'No Data') & (df_filtered['year'] != 'No Data')]

# %%
df_month_nodata_1 = df_month_nodata[df_month_nodata['year'].notnull()].copy()
df_month_nodata_1['year'] = df_month_nodata_1['year'].astype(int)

# %%
df_month_nodata_2 = df_month_nodata_1[df_month_nodata_1['year'] >= 2013]

# %%
# show the dataframe
df_month_nodata_2.head()
# Out:
#         PMID                                              Title  \
# 14  37201114  Causal effects between gut microbiota and IgA ...
# 19  35370631  The Intestinal Microbiota and Metabolites in t...
# 20  35656030  Gut Microbiome Characteristics in IgA Nephropa...
# 22  36467425  Gut-kidney axis in IgA nephropathy: Role on me...
# 27  36016798  The role and mechanism of butyrate in the prev...
#
#                                              Abstract  \
# 14  Therapeutic approaches that target the gut mic...
# 19  Emerging evidences demonstrate the involvement...
# 20  Recent data indicate the importance of gut-kid...
# 22  IgA Nephropathy (IgAN) is the commonest primar...
# 27  Diabetic kidney disease (DKD) remains the lead...
#
#                                              Journal Language of Publication  \
# 14  Frontiers in cellular and infection microbiology                     eng
# 19                         Frontiers in pharmacology                     eng
# 20  Frontiers in cellular and infection microbiology                     eng
# 22       Frontiers in cell and developmental biology                     eng
# 27                         Frontiers in microbiology                     eng
#
#     year    month                                   Publication_Type  \
# 14  2023  No Data  Journal Article, Research Support, Non-U.S. Gov't
# 19  2022  No Data                            Journal Article, Review
# 20  2022  No Data  Journal Article, Meta-Analysis, Review, System...
# 22  2022  No Data                            Journal Article, Review
# 27  2022  No Data                            Journal Article, Review
#
#                             ELocationID
# 14  1171517, 10.3389/fcimb.2023.1171517
# 19    837500, 10.3389/fphar.2022.837500
# 20    904401, 10.3389/fcimb.2022.904401
# 22    993716, 10.3389/fcell.2022.993716
# 27    961536, 10.3389/fmicb.2022.961536

# %%
# shape of the dataframe (rows, columns)
df_month_nodata_2.shape
# Out:
# (45, 9)

# %%
# filter the dataframe by year and month

# %%
df_filtered_without_nodata = df_filtered.copy()

# %%
df_filtered_without_nodata = df_filtered_without_nodata.loc[(df_filtered_without_nodata['year'] != 'No Data') &
                                                            (df_filtered_without_nodata['month'] != 'No Data')]

# %%
dict_map_month = dict((v,k) for k,v in enumerate(calendar.month_abbr))

# %%
df_filtered_without_nodata.month = df_filtered_without_nodata.month.map(dict_map_month)

# %%
df_filtered_without_nodata_1 = df_filtered_without_nodata.copy()

# %%
df_filtered_without_nodata_1['date'] = pd.to_datetime(df_filtered_without_nodata_1[['year', 'month']].assign(DAY=1))

# %%
df_filtered_without_nodata_2 = df_filtered_without_nodata_1.loc[(df_filtered_without_nodata_1['date'] >= '20130101') &
                                                                (df_filtered_without_nodata_1['date'] <= '20231001')]

# %%
# show the dataframe
df_filtered_without_nodata_2.head()
# Out:
#        PMID                                              Title  \
# 0  29760448  The gut microbiota and the brain-gut-kidney ax...
# 1  34642783     The mucosal immune system and IgA nephropathy.
# 2  34132361  Recent advances on the mechanisms of kidney st...
# 3  36127409  Mechanisms of the intestinal and urinary micro...
# 4  27847292  The role of the microbiome in kidney stone for...
#
#                                             Abstract  \
# 0  Crosstalk between the gut microbiota and the h...
# 1  The precise pathogenesis of immunoglobulin A n...
# 2  Kidney stone disease is one of the oldest dise...
# 3  Kidney stone disease affects ~10% of the globa...
# 4  Nephrolithiasis is a complex disease of worldw...
#
#                                              Journal Language of Publication  \
# 0                         Nature reviews. Nephrology                     eng
# 1                        Seminars in immunopathology                     eng
# 2        International journal of molecular medicine                     eng
# 3                            Nature reviews. Urology                     eng
# 4  International journal of surgery (London, Engl...                     eng
#
#    year  month                                   Publication_Type  \
# 0  2018      7                            Journal Article, Review
# 1  2021     10  Journal Article, Research Support, Non-U.S. Go...
# 2  2021      8                            Journal Article, Review
# 3  2022     12                            Journal Article, Review
# 4  2016     12                            Journal Article, Review
#
#                                          ELocationID       date
# 0                          10.1038/s41581-018-0018-2 2018-07-01
# 1                         10.1007/s00281-021-00871-y 2021-10-01
# 2                        149, 10.3892/ijmm.2021.4982 2021-08-01
# 3                         10.1038/s41585-022-00647-5 2022-12-01
# 4  10.1016/j.ijsu.2016.11.024, S1743-9191(16)31033-0 2016-12-01

# %%
# shape of the dataframe (rows, columns)
df_filtered_without_nodata_2.shape
# Out:
# (185, 10)

# %%
# join three dataframes

# %%
df_filtered_by_date = pd.concat([df_filtered_without_nodata_2, df_month_nodata_2, df_year_nodata], ignore_index=True, sort=False)

# %%
# show the dataframe
df_filtered_by_date.head()
# Out:
#        PMID                                              Title  \
# 0  29760448  The gut microbiota and the brain-gut-kidney ax...
# 1  34642783     The mucosal immune system and IgA nephropathy.
# 2  34132361  Recent advances on the mechanisms of kidney st...
# 3  36127409  Mechanisms of the intestinal and urinary micro...
# 4  27847292  The role of the microbiome in kidney stone for...
#
#                                             Abstract  \
# 0  Crosstalk between the gut microbiota and the h...
# 1  The precise pathogenesis of immunoglobulin A n...
# 2  Kidney stone disease is one of the oldest dise...
# 3  Kidney stone disease affects ~10% of the globa...
# 4  Nephrolithiasis is a complex disease of worldw...
#
#                                              Journal Language of Publication  \
# 0                         Nature reviews. Nephrology                     eng
# 1                        Seminars in immunopathology                     eng
# 2        International journal of molecular medicine                     eng
# 3                            Nature reviews. Urology                     eng
# 4  International journal of surgery (London, Engl...                     eng
#
#    year month                                   Publication_Type  \
# 0  2018     7                            Journal Article, Review
# 1  2021    10  Journal Article, Research Support, Non-U.S. Go...
# 2  2021     8                            Journal Article, Review
# 3  2022    12                            Journal Article, Review
# 4  2016    12                            Journal Article, Review
#
#                                          ELocationID       date
# 0                          10.1038/s41581-018-0018-2 2018-07-01
# 1                         10.1007/s00281-021-00871-y 2021-10-01
# 2                        149, 10.3892/ijmm.2021.4982 2021-08-01
# 3                         10.1038/s41585-022-00647-5 2022-12-01
# 4  10.1016/j.ijsu.2016.11.024, S1743-9191(16)31033-0 2016-12-01

# %%
# shape of the dataframe (rows, columns)
df_filtered_by_date.shape
# Out:
# (231, 10)

# %%
# filter the dataframe by study design

# %%
df_study_design = df_filtered_by_date.copy()

# %%
df_study_design['Publication_Type'].unique()
# Out:
# array(['Journal Article, Review',
#        "Journal Article, Research Support, Non-U.S. Gov't, Review",
#        "Journal Article, Research Support, Non-U.S. Gov't",
#        'Journal Article, Research Support, N.I.H., Extramural, Review',
#        "Journal Article, Review, Research Support, Non-U.S. Gov't",
#        'Journal Article', 'Congress, Overall', 'Review, Journal Article',
#        "Meta-Analysis, Systematic Review, Journal Article, Research Support, Non-U.S. Gov't",
#        'Observational Study, Journal Article',
#        'Review, Journal Article, Research Support, N.I.H., Extramural',
#        "Journal Article, Research Support, N.I.H., Extramural, Research Support, Non-U.S. Gov't",
#        'Editorial, Comment', 'Journal Article, Systematic Review',
#        'Journal Article, Research Support, N.I.H., Extramural',
#        'Journal Article, Comment',
#        "Journal Article, Research Support, Non-U.S. Gov't, Research Support, N.I.H., Extramural",
#        'Comparative Study, Journal Article',
#        'Comparative Study, Journal Article, Observational Study, Research Support, N.I.H., Extramural',
#        "Journal Article, Review, Research Support, N.I.H., Extramural, Research Support, U.S. Gov't, Non-P.H.S.",
#        'Editorial', 'English Abstract, Journal Article',
#        'Journal Article, Randomized Controlled Trial, Veterinary',
#        'Letter', 'Journal Article, Review, Systematic Review',
#        "Journal Article, Meta-Analysis, Research Support, Non-U.S. Gov't",
#        'Case Reports, Journal Article', 'Preprint',
#        "Journal Article, Review, Research Support, Non-U.S. Gov't, Systematic Review",
#        "Journal Article, Meta-Analysis, Review, Systematic Review, Research Support, Non-U.S. Gov't",
#        'Published Erratum'], dtype=object)

# %%
df_filtered_by_publication_type = df_study_design[df_study_design['Publication_Type'].str. \
                                                  contains('''Review|Comment|Congress|Veterinary|Editorial|Meta-Analysis|Letter|Preprint|Case|Reports|Erratum|Abstract''') == False]

# %%
df_filtered_by_publication_type['Publication_Type'].unique()
# Out:
# array(["Journal Article, Research Support, Non-U.S. Gov't",
#        'Journal Article', 'Observational Study, Journal Article',
#        "Journal Article, Research Support, N.I.H., Extramural, Research Support, Non-U.S. Gov't",
#        'Journal Article, Research Support, N.I.H., Extramural',
#        "Journal Article, Research Support, Non-U.S. Gov't, Research Support, N.I.H., Extramural",
#        'Comparative Study, Journal Article',
#        'Comparative Study, Journal Article, Observational Study, Research Support, N.I.H., Extramural'],
#       dtype=object)

# %%
# show the dataframe
df_filtered_by_publication_type.head()
# Out:
#         PMID                                              Title  \
# 8   35264456  Intestinal Bacterial Translocation Contributes...
# 14  35259481  Pharmacological targeting macrophage phenotype...
# 18  36371056  Sulforaphane-driven reprogramming of gut micro...
# 19  35843568  Lacticaseibacillus rhamnosus Fmb14 prevents pu...
# 21  34989745  Punicalagin alleviates renal injury <i>via</i>...
#
#                                              Abstract  \
# 8   In recent years, many studies have focused on ...
# 14  Renal fibrosis is a non-negligible pathologica...
# 18  Currently, revealing how to prevent and contro...
# 19  Hyperuricemia is a critical threat to human he...
# 21  Diabetic renal injury was associated with dysb...
#
#                                               Journal Language of Publication  \
# 8   Journal of the American Society of Nephrology ...                     eng
# 14                           Pharmacological research                     eng
# 18                       Journal of advanced research                     eng
# 19                           Pharmacological research                     eng
# 21                                    Food & function                     eng
#
#     year month                                   Publication_Type  \
# 8   2022     6  Journal Article, Research Support, Non-U.S. Gov't
# 14  2022     4  Journal Article, Research Support, Non-U.S. Gov't
# 18  2023    10                                    Journal Article
# 19  2022     8  Journal Article, Research Support, Non-U.S. Gov't
# 21  2022     1                                    Journal Article
#
#                                           ELocationID       date
# 8                              10.1681/ASN.2021060843 2022-06-01
# 14  10.1016/j.phrs.2022.106161, S1043-6618(22)00106-2 2022-04-01
# 18  10.1016/j.jare.2022.11.003, S2090-1232(22)00251-X 2023-10-01
# 19  10.1016/j.phrs.2022.106350, S1043-6618(22)00295-X 2022-08-01
# 21                                 10.1039/d1fo03343c 2022-01-01

# %%
# shape of the dataframe (rows, columns)
df_filtered_by_publication_type.shape
# Out:
# (114, 10)

# %%
# sort and format the dataframe

# %%
df_sorted = df_filtered_by_publication_type.copy()

# %%
df_sorted = df_sorted.sort_values(by=['date', 'year']).reset_index(drop = True)

# %%
df_formatted = df_sorted.copy()

# %%
df_formatted.rename(columns={'year': 'Year of Publication'}, inplace=True)
df_formatted.rename(columns={'month': 'Month of Publication'}, inplace=True)
df_formatted.rename(columns={'Publication_Type': 'Publication Type'}, inplace=True)

# %%
# full dataframe
df_full = df_formatted.copy()

# %%
# show the dataframe
df_full.head()
# Out:
#        PMID                                              Title  \
# 0  23392537                    Diet and renal stone formation.
# 1  23408055  Melamine-induced renal toxicity is mediated by...
# 2  25459132  Helicobacter pylori and urinary system stones:...
# 3  27115405  Evidence for a distinct gut microbiome in kidn...
# 4  27708409  Hyperoxaluria leads to dysbiosis and drives se...
#
#                                             Abstract  \
# 0  The relationship between diet and the formatio...
# 1  Melamine poisoning has become widely publicize...
# 2  Helicobacter pylori (H. pylori) is a atypical ...
# 3  The trillions of microbes that colonize our ad...
# 4  Hyperoxaluria due to endogenously synthesized ...
#
#                           Journal Language of Publication Year of Publication  \
# 0                  Minerva medica                     eng                2013
# 1  Science translational medicine                     eng                2013
# 2              Medical hypotheses                     eng                2014
# 3                    Urolithiasis                     eng                2016
# 4              Scientific reports                     eng                2016
#
#   Month of Publication                                   Publication Type  \
# 0                    2                                    Journal Article
# 1                    2  Journal Article, Research Support, Non-U.S. Gov't
# 2                   12                                    Journal Article
# 3                   10                 Comparative Study, Journal Article
# 4                   10  Journal Article, Research Support, Non-U.S. Gov't
#
#                                          ELocationID       date
# 0                                                    2013-02-01
# 1                       10.1126/scitranslmed.3005114 2013-02-01
# 2  10.1016/j.mehy.2014.09.016, S0306-9877(14)00341-7 2014-12-01
# 3                          10.1007/s00240-016-0882-9 2016-10-01
# 4                           34712, 10.1038/srep34712 2016-10-01

# %%
# shape of the dataframe (rows, columns)
df_full.shape
# Out:
# (114, 10)

# %%
# write the dataframe to excel
df_full.to_excel('results.xlsx', columns=['PMID', 'Title', 'Abstract', 'Journal', 'Language of Publication', 
                                                    'Year of Publication', 'Month of Publication', 'Publication Type', 'ELocationID'],
                 index=False)
